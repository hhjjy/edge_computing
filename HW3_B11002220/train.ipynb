# %% [markdown]
# ##### Install ultralytics

# %%
# !pip install ultralytics==8.0.196
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

import ultralytics
import torch
# # 检查 CUDA 是否可用
# cuda_available = torch.cuda.is_available()

# # 获取可用的 GPU 数量
# gpu_count = torch.cuda.device_count()

# # 获取每个 GPU 的名称
# gpu_names = [torch.cuda.get_device_name(i) for i in range(gpu_count)]

# print(f"CUDA Available: {cuda_available}")
# print(f"GPU Count: {gpu_count}")
# for i, name in enumerate(gpu_names):
#     print(f"GPU {i}: {name}")
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.37 🚀 Python-3.11.5 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# Setup complete ✅ (20 CPUs, 31.7 GB RAM, 761.0/953.2 GB disk)

# %% [markdown]
# ##### Install roboflow

# %%
'''
Author: Leo lion24161582@gmail.com
Date: 2024-03-29 22:06:28
LastEditors: Leo lion24161582@gmail.com
LastEditTime: 2024-04-09 23:26:32
FilePath: \edge_computing\HW3_B11002220\train.ipynb
Description: 这是默认设置,请设置`customMade`, 打开koroFileHeader查看配置 进行设置: https://github.com/OBKoro1/koro1FileHeader/wiki/%E9%85%8D%E7%BD%AE
'''
# !pip install roboflow
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="5QdKMhmNo2KNuSSrRA29")
project = rf.workspace("edge-computing").project("face_new-o34fk")
version = project.version(3)
dataset = version.download("yolov8")

#新增路徑
# path: C:\Users\Leo\Documents\NTUST\edge_computing\HW3_B11002220\face-detect-1
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.37, to fix: `pip install ultralytics==8.0.196`
# Exporting format yolov8 in progress : 85.0%
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to Face_New-3 in yolov8:: 100%|██████████| 192/192 [00:00<00:00, 315.27it/s]

# %% [markdown]
# ##### 訓練

# %%
from ultralytics import YOLO
from IPython.display import display,Image
# %cd "face-detect-1"
import os 
HOME = os.getcwd()
print(f"現在的目錄在{HOME}")

# 訓練
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=80 imgsz=640 plots=True batch=32
# Out:
# c:\Users\Leo\Documents\NTUST\edge_computing\HW3_B11002220\face-detect-1
# 現在的目錄在c:\Users\Leo\Documents\NTUST\edge_computing\HW3_B11002220\face-detect-1
# This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
# ^C
# New https://pypi.org/project/ultralytics/8.1.39 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196  Python-3.11.5 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...
