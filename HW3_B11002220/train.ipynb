# %% [markdown]
# ##### Install ultralytics

# %%
# !pip install ultralytics==8.0.196
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

import ultralytics
import torch
# # 检查 CUDA 是否可用
# cuda_available = torch.cuda.is_available()

# # 获取可用的 GPU 数量
# gpu_count = torch.cuda.device_count()

# # 获取每个 GPU 的名称
# gpu_names = [torch.cuda.get_device_name(i) for i in range(gpu_count)]

# print(f"CUDA Available: {cuda_available}")
# print(f"GPU Count: {gpu_count}")
# for i, name in enumerate(gpu_names):
#     print(f"GPU {i}: {name}")
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.37 🚀 Python-3.11.5 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# Setup complete ✅ (20 CPUs, 31.7 GB RAM, 707.1/953.2 GB disk)

# %% [markdown]
# ##### Install roboflow

# %%
# !pip install roboflow
from roboflow import Roboflow
# 下載資料
rf = Roboflow(api_key="5QdKMhmNo2KNuSSrRA29")
project = rf.workspace("edge-computing").project("face-detect-7gfux")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ---------------------------------------- 0.0/72.0 kB ? eta -:--:--
#    ---------------------- ----------------- 41.0/72.0 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 72.0/72.0 kB 1.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/158.3 kB ? eta -:--:--
#    --------------- ------------------------ 61.4/158.3 kB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 143.4/158.3 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 158.3/158.3 kB 1.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/178.7 kB ? eta -:--:--
#    ------------- -------------------------- 61.4/178.7 kB 3.2 MB/s eta 0:00:01
#    -------------------------------- ------- 143.4/178.7 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 178.7/178.7 kB 1.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/58.8 kB ? eta -:--:--
# ...

# %% [markdown]
# ##### 訓練

# %%
from ultralytics import YOLO
from IPython.display import display,Image
# %cd "face-detect-1"
import os 
HOME = os.getcwd()
print(f"現在的目錄在{HOME}")

# 訓練
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=150 imgsz=640 plots=True batch=32
# Out:
# [WinError 2] 系統找不到指定的檔案。: 'face-detect-1'
# c:\Users\Leo\Documents\NTUST\三下\Edge_computing\HW3_B11002220\face-detect-1
# 現在的目錄在c:\Users\Leo\Documents\NTUST\三下\Edge_computing\HW3_B11002220\face-detect-1
# c:\Users\Leo\Documents\NTUST\三下\Edge_computing\HW3_B11002220\.venv\Lib\site-packages\IPython\core\magics\osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# ...
# Ultralytics YOLOv8.1.37 🚀 Python-3.11.5 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...
